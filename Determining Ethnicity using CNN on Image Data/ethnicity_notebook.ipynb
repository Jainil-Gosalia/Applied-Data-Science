# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset,DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
df = pd.read_csv("age_gender.csv")
df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
#Checking for NA values
df.isna().sum()
# Out:
# age          0
# ethnicity    0
# gender       0
# img_name     0
# pixels       0
# dtype: int64

# %%
Y = df['ethnicity']
Y.nunique()
# Out:
# 5

# %%
#Getting dimensions of pixels
n_features = len(df.pixels[0].split())
print(len(df.pixels), n_features)
# Out:
# 23705 2304

# %%
#Spliting String into respective floats
X=np.zeros(shape=(23705,2304))

for i in range(len(df.pixels)):
    a=np.array(df.pixels[i].split(),dtype='float32')
    X[i]=a

# %%
X
# Out:
# array([[129., 128., 128., ..., 146., 146., 146.],
#        [164.,  74., 111., ..., 182., 170., 148.],
#        [ 67.,  70.,  71., ..., 112., 111., 108.],
#        ...,
#        [ 59.,  50.,  37., ...,  98.,  78.,  78.],
#        [ 45., 108., 120., ...,  32.,  35.,  35.],
#        [156., 161., 160., ..., 190., 184., 174.]])

# %%
X = X.reshape(-1,48,48)

# %%
X.shape
# Out:
# (23705, 48, 48)

# %%
n = len(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.33, random_state=42)

# %%
class ImageDataTrain(Dataset):
    def __init__(self):
        self.x = torch.unsqueeze(torch.from_numpy(X_train).float(),1)
        self.y = torch.unsqueeze(torch.Tensor(y_train.values).float(),1)
        self.n_samples = len(y_train)
    def __getitem__(self,index):
        return self.x[index], self.y[index]
    def __len__(self):
        return self.n_samples

dataset_tr = ImageDataTrain()    
train_loader = DataLoader(dataset=dataset_tr, batch_size=50, shuffle=True, num_workers=0)

train_iter = iter(train_loader)
train_data = train_iter.next()

# %%
class ImageDataTest(Dataset):
    def __init__(self):
        self.x = torch.unsqueeze(torch.from_numpy(X_test).float(),1)
        self.y = torch.unsqueeze(torch.Tensor(y_test.values).float(),1)
        self.n_samples = len(y_test)
    def __getitem__(self,index):
        return self.x[index], self.y[index]
    def __len__(self):
        return self.n_samples

dataset_te = ImageDataTest()    
test_loader = DataLoader(dataset=dataset_te, batch_size=500, shuffle=True, num_workers=0)

test_iter = iter(test_loader)
test_data = test_iter.next()
test_features, test_labels = test_data

# %%
class Ethinicity(nn.Module):
    def __init__(self):
        super(Ethinicity,self).__init__()
        
        self.conv_layers = nn.Sequential(
                        #Conv Layer 1
                        nn.Conv2d(in_channels=1,out_channels=6, kernel_size=3,stride=1,padding=1),
                        nn.ReLU(inplace=True),
                        nn.BatchNorm2d(4),
                        nn.MaxPool2d(kernel_size=2, stride=2),
                        #Conv Layer 2
                        nn.Conv2d(in_channels=6,out_channels=6, kernel_size=3,stride=1,padding=1),
                        nn.ReLU(inplace=True),
                        nn.BatchNorm2d(4),
                        nn.MaxPool2d(kernel_size=2, stride=2))
        
        
        self.linear_layers = nn.Sequential(
                        nn.Linear(6*12*12,5))
        
    
    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(x.size(0),-1)
        x = self.linear_layers(x)

# %%
net = Ethinicity()
print(net)
# Out:
# Ethinicity(
#   (conv_layers): Sequential(
#     (0): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (linear_layers): Sequential(
#     (0): Linear(in_features=864, out_features=5, bias=True)
#   )
# )

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.01)

# %%
num_epochs = 5

# %%
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
                
        # Forward pass
        outputs = net(images)
        loss = criterion(outputs, labels.squeeze().long())
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 5 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
# Out:
# Epoch [1/5], Step [5/318], Loss: 1.5147
# Epoch [1/5], Step [10/318], Loss: 1.5276
# Epoch [1/5], Step [15/318], Loss: 1.5080
# Epoch [1/5], Step [20/318], Loss: 1.5125
# Epoch [1/5], Step [25/318], Loss: 1.4262
# Epoch [1/5], Step [30/318], Loss: 1.4024
# Epoch [1/5], Step [35/318], Loss: 1.4671
# Epoch [1/5], Step [40/318], Loss: 1.4667
# Epoch [1/5], Step [45/318], Loss: 1.4265
# Epoch [1/5], Step [50/318], Loss: 1.4192
# Epoch [1/5], Step [55/318], Loss: 1.2973
# Epoch [1/5], Step [60/318], Loss: 1.1752
# Epoch [1/5], Step [65/318], Loss: 1.4941
# Epoch [1/5], Step [70/318], Loss: 1.4626
# Epoch [1/5], Step [75/318], Loss: 1.3859
# Epoch [1/5], Step [80/318], Loss: 1.4431
# Epoch [1/5], Step [85/318], Loss: 1.5296
# Epoch [1/5], Step [90/318], Loss: 1.4783
# Epoch [1/5], Step [95/318], Loss: 1.3422
# Epoch [1/5], Step [100/318], Loss: 1.2689
# Epoch [1/5], Step [105/318], Loss: 1.4618
# Epoch [1/5], Step [110/318], Loss: 1.3977
# Epoch [1/5], Step [115/318], Loss: 1.5105
# Epoch [1/5], Step [120/318], Loss: 1.3390
# Epoch [1/5], Step [125/318], Loss: 1.4195
# Epoch [1/5], Step [130/318], Loss: 1.5199
# Epoch [1/5], Step [135/318], Loss: 1.6266
# Epoch [1/5], Step [140/318], Loss: 1.4512
# Epoch [1/5], Step [145/318], Loss: 1.5231
# Epoch [1/5], Step [150/318], Loss: 1.4731
# Epoch [1/5], Step [155/318], Loss: 1.4939
# Epoch [1/5], Step [160/318], Loss: 1.4055
# Epoch [1/5], Step [165/318], Loss: 1.4699
# Epoch [1/5], Step [170/318], Loss: 1.4855
# Epoch [1/5], Step [175/318], Loss: 1.4903
# Epoch [1/5], Step [180/318], Loss: 1.3486
# Epoch [1/5], Step [185/318], Loss: 1.4143
# Epoch [1/5], Step [190/318], Loss: 1.3597
# Epoch [1/5], Step [195/318], Loss: 1.5351
# Epoch [1/5], Step [200/318], Loss: 1.4276
# Epoch [1/5], Step [205/318], Loss: 1.3469
# Epoch [1/5], Step [210/318], Loss: 1.5540
# Epoch [1/5], Step [215/318], Loss: 1.3777
# Epoch [1/5], Step [220/318], Loss: 1.5613
# Epoch [1/5], Step [225/318], Loss: 1.6071
# Epoch [1/5], Step [230/318], Loss: 1.3771
# Epoch [1/5], Step [235/318], Loss: 1.3622
# Epoch [1/5], Step [240/318], Loss: 1.5235
# Epoch [1/5], Step [245/318], Loss: 1.4587
# Epoch [1/5], Step [250/318], Loss: 1.4619
# Epoch [1/5], Step [255/318], Loss: 1.5209
# Epoch [1/5], Step [260/318], Loss: 1.3690
# Epoch [1/5], Step [265/318], Loss: 1.4636
# Epoch [1/5], Step [270/318], Loss: 1.4635
# Epoch [1/5], Step [275/318], Loss: 1.3743
# Epoch [1/5], Step [280/318], Loss: 1.4918
# Epoch [1/5], Step [285/318], Loss: 1.5220
# Epoch [1/5], Step [290/318], Loss: 1.5151
# Epoch [1/5], Step [295/318], Loss: 1.5779
# Epoch [1/5], Step [300/318], Loss: 1.3494
# Epoch [1/5], Step [305/318], Loss: 1.4559
# Epoch [1/5], Step [310/318], Loss: 1.4734
# Epoch [1/5], Step [315/318], Loss: 1.3473
# Epoch [2/5], Step [5/318], Loss: 1.4177
# Epoch [2/5], Step [10/318], Loss: 1.5513
# Epoch [2/5], Step [15/318], Loss: 1.4894
# Epoch [2/5], Step [20/318], Loss: 1.5131
# Epoch [2/5], Step [25/318], Loss: 1.4555
# Epoch [2/5], Step [30/318], Loss: 1.3979
# Epoch [2/5], Step [35/318], Loss: 1.4236
# Epoch [2/5], Step [40/318], Loss: 1.4271
# Epoch [2/5], Step [45/318], Loss: 1.3691
# Epoch [2/5], Step [50/318], Loss: 1.3237
# Epoch [2/5], Step [55/318], Loss: 1.5654
# Epoch [2/5], Step [60/318], Loss: 1.5048
# Epoch [2/5], Step [65/318], Loss: 1.3293
# Epoch [2/5], Step [70/318], Loss: 1.4996
# Epoch [2/5], Step [75/318], Loss: 1.6640
# Epoch [2/5], Step [80/318], Loss: 1.4059
# Epoch [2/5], Step [85/318], Loss: 1.3412
# Epoch [2/5], Step [90/318], Loss: 1.4299
# Epoch [2/5], Step [95/318], Loss: 1.4960
# Epoch [2/5], Step [100/318], Loss: 1.3105
# Epoch [2/5], Step [105/318], Loss: 1.5174
# Epoch [2/5], Step [110/318], Loss: 1.3318
# Epoch [2/5], Step [115/318], Loss: 1.2657
# Epoch [2/5], Step [120/318], Loss: 1.5136
# Epoch [2/5], Step [125/318], Loss: 1.5091
# Epoch [2/5], Step [130/318], Loss: 1.5548
# Epoch [2/5], Step [135/318], Loss: 1.4846
# Epoch [2/5], Step [140/318], Loss: 1.3797
# Epoch [2/5], Step [145/318], Loss: 1.4661
# Epoch [2/5], Step [150/318], Loss: 1.4846
# Epoch [2/5], Step [155/318], Loss: 1.4508
# Epoch [2/5], Step [160/318], Loss: 1.5007
# Epoch [2/5], Step [165/318], Loss: 1.3833
# Epoch [2/5], Step [170/318], Loss: 1.4264
# Epoch [2/5], Step [175/318], Loss: 1.4733
# Epoch [2/5], Step [180/318], Loss: 1.3268
# Epoch [2/5], Step [185/318], Loss: 1.3924
# Epoch [2/5], Step [190/318], Loss: 1.4824
# Epoch [2/5], Step [195/318], Loss: 1.3717
# Epoch [2/5], Step [200/318], Loss: 1.4219
# Epoch [2/5], Step [205/318], Loss: 1.5212
# Epoch [2/5], Step [210/318], Loss: 1.4826
# Epoch [2/5], Step [215/318], Loss: 1.5176
# Epoch [2/5], Step [220/318], Loss: 1.5678
# Epoch [2/5], Step [225/318], Loss: 1.4877
# Epoch [2/5], Step [230/318], Loss: 1.3433
# Epoch [2/5], Step [235/318], Loss: 1.3628
# Epoch [2/5], Step [240/318], Loss: 1.4448
# Epoch [2/5], Step [245/318], Loss: 1.4451
# Epoch [2/5], Step [250/318], Loss: 1.5227
# Epoch [2/5], Step [255/318], Loss: 1.4024
# Epoch [2/5], Step [260/318], Loss: 1.4838
# Epoch [2/5], Step [265/318], Loss: 1.3891
# Epoch [2/5], Step [270/318], Loss: 1.4502
# Epoch [2/5], Step [275/318], Loss: 1.5717
# Epoch [2/5], Step [280/318], Loss: 1.4536
# Epoch [2/5], Step [285/318], Loss: 1.5141
# Epoch [2/5], Step [290/318], Loss: 1.5721
# Epoch [2/5], Step [295/318], Loss: 1.4198
# Epoch [2/5], Step [300/318], Loss: 1.4554
# Epoch [2/5], Step [305/318], Loss: 1.5059
# Epoch [2/5], Step [310/318], Loss: 1.4240
# Epoch [2/5], Step [315/318], Loss: 1.4700
# Epoch [3/5], Step [5/318], Loss: 1.5227
# Epoch [3/5], Step [10/318], Loss: 1.4163
# Epoch [3/5], Step [15/318], Loss: 1.5267
# Epoch [3/5], Step [20/318], Loss: 1.5227
# Epoch [3/5], Step [25/318], Loss: 1.4173
# Epoch [3/5], Step [30/318], Loss: 1.4952
# Epoch [3/5], Step [35/318], Loss: 1.5740
# Epoch [3/5], Step [40/318], Loss: 1.3747
# Epoch [3/5], Step [45/318], Loss: 1.5559
# Epoch [3/5], Step [50/318], Loss: 1.5085
# Epoch [3/5], Step [55/318], Loss: 1.3090
# Epoch [3/5], Step [60/318], Loss: 1.3830
# Epoch [3/5], Step [65/318], Loss: 1.5897
# Epoch [3/5], Step [70/318], Loss: 1.3142
# Epoch [3/5], Step [75/318], Loss: 1.2766
# Epoch [3/5], Step [80/318], Loss: 1.4393
# Epoch [3/5], Step [85/318], Loss: 1.5542
# Epoch [3/5], Step [90/318], Loss: 1.4508
# Epoch [3/5], Step [95/318], Loss: 1.6340
# Epoch [3/5], Step [100/318], Loss: 1.5699
# Epoch [3/5], Step [105/318], Loss: 1.3003
# Epoch [3/5], Step [110/318], Loss: 1.4692
# Epoch [3/5], Step [115/318], Loss: 1.4292
# Epoch [3/5], Step [120/318], Loss: 1.4958
# Epoch [3/5], Step [125/318], Loss: 1.5038
# Epoch [3/5], Step [130/318], Loss: 1.2508
# Epoch [3/5], Step [135/318], Loss: 1.4987
# Epoch [3/5], Step [140/318], Loss: 1.4588
# Epoch [3/5], Step [145/318], Loss: 1.5326
# Epoch [3/5], Step [150/318], Loss: 1.4055
# Epoch [3/5], Step [155/318], Loss: 1.3535
# Epoch [3/5], Step [160/318], Loss: 1.2666
# Epoch [3/5], Step [165/318], Loss: 1.4997
# Epoch [3/5], Step [170/318], Loss: 1.4553
# Epoch [3/5], Step [175/318], Loss: 1.4784
# Epoch [3/5], Step [180/318], Loss: 1.4262
# Epoch [3/5], Step [185/318], Loss: 1.4671
# Epoch [3/5], Step [190/318], Loss: 1.3700
# Epoch [3/5], Step [195/318], Loss: 1.2957
# Epoch [3/5], Step [200/318], Loss: 1.4889
# Epoch [3/5], Step [205/318], Loss: 1.3168
# Epoch [3/5], Step [210/318], Loss: 1.4599
# Epoch [3/5], Step [215/318], Loss: 1.5418
# Epoch [3/5], Step [220/318], Loss: 1.4953
# Epoch [3/5], Step [225/318], Loss: 1.4391
# Epoch [3/5], Step [230/318], Loss: 1.3720
# Epoch [3/5], Step [235/318], Loss: 1.4494
# Epoch [3/5], Step [240/318], Loss: 1.4763
# Epoch [3/5], Step [245/318], Loss: 1.4024
# Epoch [3/5], Step [250/318], Loss: 1.4838
# Epoch [3/5], Step [255/318], Loss: 1.4546
# Epoch [3/5], Step [260/318], Loss: 1.3472
# Epoch [3/5], Step [265/318], Loss: 1.5528
# Epoch [3/5], Step [270/318], Loss: 1.4356
# Epoch [3/5], Step [275/318], Loss: 1.5706
# Epoch [3/5], Step [280/318], Loss: 1.4395
# Epoch [3/5], Step [285/318], Loss: 1.3930
# Epoch [3/5], Step [290/318], Loss: 1.4960
# Epoch [3/5], Step [295/318], Loss: 1.5077
# Epoch [3/5], Step [300/318], Loss: 1.5897
# Epoch [3/5], Step [305/318], Loss: 1.3694
# Epoch [3/5], Step [310/318], Loss: 1.3920
# Epoch [3/5], Step [315/318], Loss: 1.4778
# Epoch [4/5], Step [5/318], Loss: 1.3588
# Epoch [4/5], Step [10/318], Loss: 1.5059
# Epoch [4/5], Step [15/318], Loss: 1.4086
# Epoch [4/5], Step [20/318], Loss: 1.4294
# Epoch [4/5], Step [25/318], Loss: 1.4545
# Epoch [4/5], Step [30/318], Loss: 1.4529
# Epoch [4/5], Step [35/318], Loss: 1.4995
# Epoch [4/5], Step [40/318], Loss: 1.4512
# Epoch [4/5], Step [45/318], Loss: 1.4618
# Epoch [4/5], Step [50/318], Loss: 1.4891
# Epoch [4/5], Step [55/318], Loss: 1.5280
# Epoch [4/5], Step [60/318], Loss: 1.4736
# Epoch [4/5], Step [65/318], Loss: 1.3125
# Epoch [4/5], Step [70/318], Loss: 1.4165
# Epoch [4/5], Step [75/318], Loss: 1.4211
# Epoch [4/5], Step [80/318], Loss: 1.4894
# Epoch [4/5], Step [85/318], Loss: 1.5298
# Epoch [4/5], Step [90/318], Loss: 1.3425
# Epoch [4/5], Step [95/318], Loss: 1.4213
# Epoch [4/5], Step [100/318], Loss: 1.4099
# Epoch [4/5], Step [105/318], Loss: 1.6544
# Epoch [4/5], Step [110/318], Loss: 1.6017
# Epoch [4/5], Step [115/318], Loss: 1.4592
# Epoch [4/5], Step [120/318], Loss: 1.3817
# Epoch [4/5], Step [125/318], Loss: 1.3585
# Epoch [4/5], Step [130/318], Loss: 1.4592
# Epoch [4/5], Step [135/318], Loss: 1.4933
# Epoch [4/5], Step [140/318], Loss: 1.4230
# Epoch [4/5], Step [145/318], Loss: 1.3615
# Epoch [4/5], Step [150/318], Loss: 1.4615
# Epoch [4/5], Step [155/318], Loss: 1.3660
# Epoch [4/5], Step [160/318], Loss: 1.4865
# Epoch [4/5], Step [165/318], Loss: 1.5177
# Epoch [4/5], Step [170/318], Loss: 1.4234
# Epoch [4/5], Step [175/318], Loss: 1.3777
# Epoch [4/5], Step [180/318], Loss: 1.4183
# Epoch [4/5], Step [185/318], Loss: 1.2978
# Epoch [4/5], Step [190/318], Loss: 1.5206
# Epoch [4/5], Step [195/318], Loss: 1.4730
# Epoch [4/5], Step [200/318], Loss: 1.4518
# Epoch [4/5], Step [205/318], Loss: 1.5090
# Epoch [4/5], Step [210/318], Loss: 1.5338
# Epoch [4/5], Step [215/318], Loss: 1.3783
# Epoch [4/5], Step [220/318], Loss: 1.4978
# Epoch [4/5], Step [225/318], Loss: 1.5586
# Epoch [4/5], Step [230/318], Loss: 1.4904
# Epoch [4/5], Step [235/318], Loss: 1.3623
# Epoch [4/5], Step [240/318], Loss: 1.4755
# Epoch [4/5], Step [245/318], Loss: 1.4541
# Epoch [4/5], Step [250/318], Loss: 1.4079
# Epoch [4/5], Step [255/318], Loss: 1.4138
# Epoch [4/5], Step [260/318], Loss: 1.3632
# Epoch [4/5], Step [265/318], Loss: 1.4927
# Epoch [4/5], Step [270/318], Loss: 1.4927
# Epoch [4/5], Step [275/318], Loss: 1.4941
# Epoch [4/5], Step [280/318], Loss: 1.4818
# Epoch [4/5], Step [285/318], Loss: 1.5356
# Epoch [4/5], Step [290/318], Loss: 1.4911
# Epoch [4/5], Step [295/318], Loss: 1.3927
# Epoch [4/5], Step [300/318], Loss: 1.5083
# Epoch [4/5], Step [305/318], Loss: 1.4638
# Epoch [4/5], Step [310/318], Loss: 1.4594
# Epoch [4/5], Step [315/318], Loss: 1.3997
# Epoch [5/5], Step [5/318], Loss: 1.4830
# Epoch [5/5], Step [10/318], Loss: 1.4754
# Epoch [5/5], Step [15/318], Loss: 1.3625
# Epoch [5/5], Step [20/318], Loss: 1.3663
# Epoch [5/5], Step [25/318], Loss: 1.3407
# Epoch [5/5], Step [30/318], Loss: 1.3874
# Epoch [5/5], Step [35/318], Loss: 1.4251
# Epoch [5/5], Step [40/318], Loss: 1.4738
# Epoch [5/5], Step [45/318], Loss: 1.5081
# Epoch [5/5], Step [50/318], Loss: 1.4823
# Epoch [5/5], Step [55/318], Loss: 1.4474
# Epoch [5/5], Step [60/318], Loss: 1.4399
# Epoch [5/5], Step [65/318], Loss: 1.5346
# Epoch [5/5], Step [70/318], Loss: 1.4794
# Epoch [5/5], Step [75/318], Loss: 1.5026
# Epoch [5/5], Step [80/318], Loss: 1.4755
# Epoch [5/5], Step [85/318], Loss: 1.4336
# Epoch [5/5], Step [90/318], Loss: 1.3941
# Epoch [5/5], Step [95/318], Loss: 1.5074
# Epoch [5/5], Step [100/318], Loss: 1.3907
# Epoch [5/5], Step [105/318], Loss: 1.4124
# Epoch [5/5], Step [110/318], Loss: 1.5818
# Epoch [5/5], Step [115/318], Loss: 1.3976
# Epoch [5/5], Step [120/318], Loss: 1.4402
# Epoch [5/5], Step [125/318], Loss: 1.4027
# Epoch [5/5], Step [130/318], Loss: 1.4271
# Epoch [5/5], Step [135/318], Loss: 1.5827
# Epoch [5/5], Step [140/318], Loss: 1.4977
# Epoch [5/5], Step [145/318], Loss: 1.6327
# Epoch [5/5], Step [150/318], Loss: 1.3099
# Epoch [5/5], Step [155/318], Loss: 1.4316
# Epoch [5/5], Step [160/318], Loss: 1.3428
# Epoch [5/5], Step [165/318], Loss: 1.3210
# Epoch [5/5], Step [170/318], Loss: 1.3347
# Epoch [5/5], Step [175/318], Loss: 1.5265
# Epoch [5/5], Step [180/318], Loss: 1.5863
# Epoch [5/5], Step [185/318], Loss: 1.4462
# Epoch [5/5], Step [190/318], Loss: 1.4339
# Epoch [5/5], Step [195/318], Loss: 1.4629
# Epoch [5/5], Step [200/318], Loss: 1.5834
# Epoch [5/5], Step [205/318], Loss: 1.4324
# Epoch [5/5], Step [210/318], Loss: 1.5946
# Epoch [5/5], Step [215/318], Loss: 1.4021
# Epoch [5/5], Step [220/318], Loss: 1.4428
# Epoch [5/5], Step [225/318], Loss: 1.4944
# Epoch [5/5], Step [230/318], Loss: 1.4558
# Epoch [5/5], Step [235/318], Loss: 1.4403
# Epoch [5/5], Step [240/318], Loss: 1.4841
# Epoch [5/5], Step [245/318], Loss: 1.4440
# Epoch [5/5], Step [250/318], Loss: 1.5277
# Epoch [5/5], Step [255/318], Loss: 1.4638
# Epoch [5/5], Step [260/318], Loss: 1.3206
# Epoch [5/5], Step [265/318], Loss: 1.3962
# Epoch [5/5], Step [270/318], Loss: 1.5374
# Epoch [5/5], Step [275/318], Loss: 1.4622
# Epoch [5/5], Step [280/318], Loss: 1.3677
# Epoch [5/5], Step [285/318], Loss: 1.3531
# Epoch [5/5], Step [290/318], Loss: 1.3587
# Epoch [5/5], Step [295/318], Loss: 1.4520
# Epoch [5/5], Step [300/318], Loss: 1.5263
# Epoch [5/5], Step [305/318], Loss: 1.4373
# Epoch [5/5], Step [310/318], Loss: 1.3421
# Epoch [5/5], Step [315/318], Loss: 1.4445

# %%
net.eval()
pred_labels = net(test_features)

# %%
# Save the model checkpoint
torch.save(net.state_dict(), 'model.ckpt')
